# %% [markdown]
# <a href="https://colab.research.google.com/github/owenc8/A2-Rule-Based-System/blob/main/A2_IAT460.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install ColabTurtle
# Out:
# Collecting ColabTurtle
#   Downloading ColabTurtle-2.1.0.tar.gz (6.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ColabTurtle
#   Building wheel for ColabTurtle (setup.py) ... done
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7642 sha256=fae795fe7575a13930e76dd2a32c23339f3f72bb2a0bc4e56ff43aa6223f34fe
#   Stored in directory: /root/.cache/pip/wheels/f6/9e/81/137e7da25129474562d30f8660be599e5c8d79228cb747e5b9
# Successfully built ColabTurtle
# Installing collected packages: ColabTurtle
# Successfully installed ColabTurtle-2.1.0

# %%
import ColabTurtle.Turtle as t
from IPython.display import clear_output
import random

# %% [markdown]
# lab 3 L system code

# %%
def create_l_system(iterations, axiom, rules):
    """Generate L-System instructions based on axiom and rules."""

    result = axiom
    for _ in range(iterations):
        new_string = ""

        for char in result:
            new_string += rules.get(char, char)
        result = new_string
    return result

def turtle_bounds():
  if t.xcor() > t.window_width() or t.xcor() < 0 or t.ycor() > t.window_height() or t.ycor() < 0:
    return True
  return False

def draw_l_system(instructions, angle, distance):
    """Draw the L-System using turtle graphics.

    Parameters:
    - instructions: string of L-System commands
    - angle: turning angle in degrees
    - distance: forward movement distance
    """

    stack = []
    for cmd in instructions:
        if cmd == 'F':  # Move forward and draw
            t.forward(distance)
        elif cmd == 'f':  # Move forward without drawing
            t.penup()
            t.forward(distance)
            t.pendown()
        elif cmd == '+':  # Turn right
            t.right(angle)
        elif cmd == '-':  # Turn left
            t.left(angle)
        elif cmd == '[':  # Save current state
            stack.append((t.position(), t.heading()))
        elif cmd == ']':  # Restore previous state
            position, heading = stack.pop()
            t.penup()
            t.goto(position)
            t.setheading(heading)
            t.pendown()

def setup_turtle():
        t.initializeTurtle()
        t.hideturtle()
        t.speed(13)  # Fastest speed
        t.penup()
        t.goto(t.window_width() // 2, t.window_height()-100)  # Start position
        t.pendown()

def setup_turtle_bottom():
        t.initializeTurtle()
        t.hideturtle()
        t.speed(13)  # Fastest speed
        t.penup()
        t.goto(t.window_width() // 2, t.window_height())  # Start position
        t.pendown()



def draw_l_system_randAngle(instructions, distance):

    stack = []
    for cmd in instructions:
        if cmd == 'F':  # Move forward and draw
            t.forward(distance)
        elif cmd == 'f':  # Move forward without drawing
            t.penup()
            t.forward(distance)
            t.pendown()
        elif cmd == '+':  # Turn right
            t.right(random.randint(15,45))
        elif cmd == '-':  # Turn left
            t.left(random.randint(15,45))
        elif cmd == '[':  # Save current state
            stack.append((t.position(), t.heading()))
        elif cmd == ']':  # Restore previous state
            position, heading = stack.pop()
            t.penup()
            t.goto(position)
            t.setheading(heading)
            t.pendown()

# %% [markdown]
# Trees

# %%
# axiom = FX
# X -> X+YF+
# Y -> -FX-Y
# angle = 90
import random

# cool pattern
# tree_axiom = "FXX"
# tree_rules = {
#     "Y": "-FX-Y",
#     "X": "X+YF+"
# }

#geometric pattern
# tree_axiom = "X"
# tree_rules = {
#     "F": "F+F--F+F",
#     "X": "F+[[X]-X]-F[-FX]+X"


# }

possible_axioms = ["FXY", "FX", "FXX", "FFX"]
possible_rules = [
    {
        "Y": "-FX-Y",
        "X": "X+YF+"
    },
    {
        "Y": "+FX+Y",
        "X": "X-YF-"
    },
    {
        "Y": "FX-Y",
        "X": "X+YF"
    },
    {
        "Y": "FX+Y",
        "X": "X-YF"
    }
]
tree_axiom = random.choice(possible_axioms)  # Randomly choose an axiom
tree_rules = random.choice(possible_rules)

print("Selected Axiom:", tree_axiom)
print("Selected Rules:", tree_rules)

 # Basic branching rule
tree_iterations = 3
tree_angle = random.randint(60,90)

size=2
# Generate and draw

setup_turtle()
def changeColour():
  red = random.randint(40,120)
  green = random.randint(150,255)
  blue = random.randint(220,255)
  t.pencolor(red,green,blue)


t.pensize(size)

# initial_color = (40, 40, 255)
red = 40
green = 40
blue = 255
t.pencolor(red,green,blue)
for i in range(3):

  t.pensize(size)
  changeColour()

  tree_instructions = create_l_system(tree_iterations, tree_axiom, tree_rules)
  draw_l_system(tree_instructions,tree_angle, 7)
# Out:
# Selected Axiom: FXX
# Selected Rules: {'Y': '-FX-Y', 'X': 'X+YF+'}
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="400" x2="400.0" y2="393.0" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="400.0" y1="393.0" x2="406.999" y2="392.878" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="406.999" y1="392.878" x2="407.243" y2="399.874" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="407.243" y1="399.874" x2="414.242" y2="399.752" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="414.242" y1="399.752" x2="414.486" y2="406.748" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="414.486" y1="406.748" x2="407.496" y2="407.114" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="407.496" y1="407.114" x2="407.74" y2="414.11" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="407.74" y1="414.11" x2="414.739" y2="413.988" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="414.739" y1="413.988" x2="414.983" y2="420.984" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="414.983" y1="420.984" x2="407.993" y2="421.35" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="407.993" y1="421.35" x2="407.505" y2="414.367" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="407.505" y1="414.367" x2="400.515" y2="414.733" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="400.515" y1="414.733" x2="400.759" y2="421.729" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="400.759" y1="421.729" x2="393.769" y2="422.095" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="393.769" y1="422.095" x2="394.013" y2="429.091" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="394.013" y1="429.091" x2="401.012" y2="428.969" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="401.012" y1="428.969" x2="401.256" y2="435.965" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="401.256" y1="435.965" x2="394.266" y2="436.331" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="394.266" y1="436.331" x2="393.778" y2="429.348" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="393.778" y1="429.348" x2="386.788" y2="429.714" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="386.788" y1="429.714" x2="386.3" y2="422.731" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="386.3" y1="422.731" x2="393.273" y2="422.121" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="393.273" y1="422.121" x2="392.785" y2="415.138" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="392.785" y1="415.138" x2="385.795" y2="415.504" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="385.795" y1="415.504" x2="386.039" y2="422.5" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="386.039" y1="422.5" x2="379.049" y2="422.866" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="379.049" y1="422.866" x2="378.561" y2="415.883" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="378.561" y1="415.883" x2="371.571" y2="416.249" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="371.571" y1="416.249" x2="371.815" y2="423.245" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="371.815" y1="423.245" x2="364.825" y2="423.611" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="364.825" y1="423.611" x2="365.069" y2="430.607" stroke-linecap="round" style="stroke:rgb(51,215,248);stroke-width:2"/><line x1="365.069" y1="430.607" x2="372.068" y2="430.4 ...

# %%
import random


possible_axioms = ["F", "FF", "FFF"]
possible_rules = [
    {
        "F": "F[+X][-X]FX",
       "X":"[F[++F][--F]]"

    },
    {
        "F": "F[+X]FX",
       "X":"[F[++F][--F]]"


    },
    {
        "F": "F[-X]FX",
       "X":"[F[++F][--F]]"


    },
    {
        "F": "F[+X][-X]",
       "X":"[F[++F][--F]]"


    },
    {
        "F": "F[+X][-X]X",
       "X":"[F[++F][--F]]"


    }
]


tree_axiom = random.choice(possible_axioms)
tree_rules = random.choice(possible_rules)
print("Selected Axiom:", tree_axiom)
print("Selected Rules:", tree_rules)
 # Basic branching rule
tree_iterations = 6



# Generate and draw

setup_turtle_bottom()

def changeColour():
  red = random.randint(40,120)
  green = random.randint(150,255)
  blue = random.randint(220,255)
  t.pencolor(red,green,blue)


t.pensize(1)



tree_instructions = create_l_system(tree_iterations, tree_axiom, tree_rules)
draw_l_system_randAngle(tree_instructions, 8)
# Out:
# Selected Axiom: FFF
# Selected Rules: {'F': 'F[+X][-X]FX', 'X': '[F[++F][--F]]'}
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="500" x2="400.0" y2="492.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="492.0" x2="400.0" y2="484.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="484.0" x2="403.507" y2="476.81" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="403.507" y1="476.81" x2="410.697" y2="473.303" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="403.507" y1="476.81" x2="400.0" y2="469.62" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="484.0" x2="396.244" y2="476.936" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="396.244" y1="476.936" x2="400.833" y2="470.383" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="396.244" y1="476.936" x2="388.594" y2="474.597" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="484.0" x2="400.0" y2="476.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="476.0" x2="400.0" y2="468.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="468.0" x2="400.0" y2="460.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="460.0" x2="406.709" y2="455.643" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="460.0" x2="394.752" y2="453.962" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="468.0" x2="405.353" y2="462.055" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="405.353" y1="462.055" x2="410.706" y2="456.11" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="410.706" y1="456.11" x2="417.49" y2="460.349" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="417.49" y1="460.349" x2="424.274" y2="464.588" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="410.706" y1="456.11" x2="407.452" y2="448.802" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="407.452" y1="448.802" x2="404.198" y2="441.494" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="468.0" x2="397.003" y2="460.583" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="397.003" y1="460.583" x2="394.006" y2="453.166" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="394.006" y1="453.166" x2="398.245" y2="446.382" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="398.245" y1="446.382" x2="402.484" y2="439.598" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="394.006" y1="453.166" x2="386.589" y2="456.163" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="386.589" y1="456.163" x2="379.172" y2="459.16" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="468.0" x2="400.0" y2="460.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="460.0" x2="400.0" y2="452.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="452.0" x2="404.925" y2="445.696" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="404.925" y1="445.696" x2="412.443" y2="442.96" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="404.925" y1="445.696" x2="399.89" y2="439.479" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="452.0" x2="394.858" y2="445.872" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="394.858" y1="445.872" x2="394.161" y2="437.902" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="394.858" y1="445.872" x2="386.859" y2="445.732" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="452.0" x2="400.0" y2="444.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="444.0" x2="400.0" y2="436.0" stroke-linecap="round" style="stroke:white;s ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-a7bc61b17f56> in <cell line: 0>()
#      61
#      62 tree_instructions = create_l_system(tree_iterations, tree_axiom, tree_rules)
# ---> 63 draw_l_system_randAngle(tree_instructions, 8)
#
# <ipython-input-25-c20ee9c386f4> in draw_l_system_randAngle(instructions, distance)
#      83             position, heading = stack.pop()
#      84             t.penup()
# ---> 85             t.goto(position)
#      86             t.setheading(heading)
#      87             t.pendown()
#
# /usr/local/lib/python3.11/dist-packages/ColabTurtle/Turtle.py in goto(x, y)
#     323         raise ValueError('new y position must be a number.')
#     324     if y < 0:
# --> 325         raise ValueError('new y position must be non-negative.')
#     326     _moveToNewPosition((x, y))
#     327
#
# ValueError: new y position must be non-negative.

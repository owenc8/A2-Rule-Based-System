# %% [markdown]
# <a href="https://colab.research.google.com/github/owenc8/A2-Rule-Based-System/blob/main/A2_IAT460.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install ColabTurtle
# Out:
# Collecting ColabTurtle
#   Downloading ColabTurtle-2.1.0.tar.gz (6.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ColabTurtle
#   Building wheel for ColabTurtle (setup.py) ... done
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7642 sha256=7430c92c7e65ef2be8f478833e24d1dce5ed2cf3bea68a2ef4640870ca96f18e
#   Stored in directory: /root/.cache/pip/wheels/f6/9e/81/137e7da25129474562d30f8660be599e5c8d79228cb747e5b9
# Successfully built ColabTurtle
# Installing collected packages: ColabTurtle
# Successfully installed ColabTurtle-2.1.0

# %%
import ColabTurtle.Turtle as t
from IPython.display import clear_output
import random

# %% [markdown]
# lab 3 L system code

# %%
def create_l_system(iterations, axiom, rules):

    result = axiom
    for _ in range(iterations):
        new_string = ""

        for char in result:
            new_string += rules.get(char, char)
        result = new_string
    return result


def setup_turtle_bottom():
        t.initializeTurtle()
        t.hideturtle()
        t.speed(13)
        t.penup()
        t.goto(t.window_width() // 2, t.window_height())  # Start position
        t.pendown()



def draw_l_system_randAngle(instructions, distance,branchWidth):

    stack = []
    for cmd in instructions:
        if cmd == 'F':  # Move forward and draw
            t.pensize(branchWidth)
            t.pencolor(random.randint(90,110),random.randint(60,80),random.randint(25,35))
            t.forward(distance)
            if branchWidth > 1:
                branchWidth -=1
            elif branchWidth ==1:
              branchWidth = 1
        elif cmd == 'f':  # Move forward without drawing
            t.penup()
            t.forward(distance)
            t.pendown()
        elif cmd == '+':  # Turn right
            t.right(random.randint(15,45))
        elif cmd == '-':  # Turn left
            t.left(random.randint(15,45))
        elif cmd == '[':  # Save current state
            stack.append((t.position(), t.heading()))
        elif cmd == ']':  # Restore previous state
            position, heading = stack.pop()
            t.penup()
            t.goto(position)
            t.setheading(heading)
            t.pendown()
        elif cmd == 'L': #leaf
          t.forward(distance)
          t.pensize(2)
          t.pencolor(random.randint(30,100),random.randint(200,240),0)

# %% [markdown]
# # **Trees**

# %% [markdown]
# In the function "create_Tree()" there are 4 parameters the user can change.
#
# In order they are:
# 1.   Branch length(length of each branch segment)
# 2.   Trunk thickness(starting thickness of trunk)
# 3.   Iterations(overall branch length)
# 4.   Density(number of trees drawn on top of each other to add more branches)

# %%
# Plant parameters
tree_axiom = "X"
possible_rules = [
    {
        "X": "F+[[X]-X]-FL[-FX]+XL",
        "F": "FF",
        "L" :"[L[++L][--L]], L"
    },
    {
        "X": "F+[[X]-X]-FL[-FX]++XL",
        "F": "FF",
        "L" :"[L[++L][--L]], L"
    },
    {
        "X": "F+[[X]--X]-FL[-FX]+XL",
        "F": "FF",
        "L" :"[L[++L][--L]], L"
    },
    {
        "X": "F+[[+X]-X]-FL[--FX]+XL",
        "F": "FF",
        "L" :"[L[++L][--L]], L"
    },
     {
        "X": "F++[[-X]-X]-FL[-FX]+XL",
        "F": "FF",
        "L" :"[L[++L][--L]], L"
    }
]
def randomize_rules():
  return random.choice(possible_rules)

chosen_rules = randomize_rules()
print("Branching pattern:")
print(chosen_rules)

def reset_turtle():
  t.penup()
  t.goto(t.window_width() // 2, t.window_height())
  t.pendown()
  t.setheading(270)
# Generate and draw
setup_turtle_bottom()

def create_Tree(branchLen,trunkThickness,plant_iterations,density):
  for i in range(density):
    tree_rules = randomize_rules()
    plant_instructions = create_l_system(plant_iterations, tree_axiom, tree_rules)
    draw_l_system_randAngle(plant_instructions, branchLen,trunkThickness)
    reset_turtle()

####################
#TREE FUNCTION

create_Tree(10,10,2,10)
# Out:
# Branching pattern:
# {'X': 'F+[[X]-X]-FL[-FX]+XL', 'F': 'FF', 'L': '[L[++L][--L]], L'}
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="500" x2="400.0" y2="490.0" stroke-linecap="round" style="stroke:rgb(95,71,29);stroke-width:10"/><line x1="400.0" y1="490.0" x2="400.0" y2="480.0" stroke-linecap="round" style="stroke:rgb(102,65,25);stroke-width:9"/><line x1="400.0" y1="480.0" x2="406.691" y2="472.569" stroke-linecap="round" style="stroke:rgb(106,63,33);stroke-width:8"/><line x1="406.691" y1="472.569" x2="411.539" y2="463.823" stroke-linecap="round" style="stroke:rgb(91,76,28);stroke-width:7"/><line x1="411.539" y1="463.823" x2="416.387" y2="455.077" stroke-linecap="round" style="stroke:rgb(91,76,28);stroke-width:7"/><line x1="416.387" y1="455.077" x2="418.466" y2="445.296" stroke-linecap="round" style="stroke:rgb(110,63,32);stroke-width:6"/><line x1="416.387" y1="455.077" x2="426.385" y2="455.252" stroke-linecap="round" style="stroke:rgb(110,63,32);stroke-width:6"/><line x1="400.0" y1="480.0" x2="404.54" y2="471.09" stroke-linecap="round" style="stroke:rgb(90,65,32);stroke-width:5"/><line x1="404.54" y1="471.09" x2="406.959" y2="461.387" stroke-linecap="round" style="stroke:rgb(90,62,30);stroke-width:4"/><line x1="406.959" y1="461.387" x2="409.378" y2="451.684" stroke-linecap="round" style="stroke:rgb(90,62,30);stroke-width:4"/><line x1="409.378" y1="451.684" x2="407.128" y2="441.94" stroke-linecap="round" style="stroke:rgb(98,74,26);stroke-width:3"/><line x1="409.378" y1="451.684" x2="419.226" y2="449.948" stroke-linecap="round" style="stroke:rgb(98,74,26);stroke-width:3"/><line x1="400.0" y1="480.0" x2="404.384" y2="471.012" stroke-linecap="round" style="stroke:rgb(99,72,32);stroke-width:2"/><line x1="404.384" y1="471.012" x2="408.768" y2="462.024" stroke-linecap="round" style="stroke:rgb(105,74,30);stroke-width:1"/><line x1="408.768" y1="462.024" x2="413.152" y2="453.036" stroke-linecap="round" style="stroke:rgb(105,74,30);stroke-width:1"/><line x1="413.152" y1="453.036" x2="423.138" y2="452.513" stroke-linecap="round" style="stroke:rgb(49,216,0);stroke-width:2"/><line x1="413.152" y1="453.036" x2="404.406" y2="448.188" stroke-linecap="round" style="stroke:rgb(92,219,0);stroke-width:2"/><line x1="408.768" y1="462.024" x2="413.152" y2="453.036" stroke-linecap="round" style="stroke:rgb(59,230,0);stroke-width:2"/><line x1="413.152" y1="453.036" x2="413.85" y2="443.06" stroke-linecap="round" style="stroke:rgb(109,64,35);stroke-width:1"/><line x1="413.85" y1="443.06" x2="414.548" y2="433.084" stroke-linecap="round" style="stroke:rgb(102,62,25);stroke-width:1"/><line x1="414.548" y1="433.084" x2="415.246" y2="423.108" stroke-linecap="round" style="stroke:rgb(103,80,28);stroke-width:1"/><line x1="415.246" y1="423.108" x2="411.5" y2="413.836" stroke-linecap="round" style="stroke:rgb(109,69,27);stroke-width:1"/><line x1="411.5" y1="413.836" x2="407.754" y2="404.564" stroke-linecap="round" style="stroke:rgb(109,69,27);stroke-width:1"/><line x1="407.754" y1="404.564" x2="399.464" y2="398.972" stroke-linecap="round" style="stroke:rgb(104,75,34);stroke-width:1"/><line x1="407.754" y1="404.564" x2="409.662" y2="394.748" stroke-linecap="round" style="stroke:rgb(104,75,34);stroke-width:1"/><line x1="413.152" y1="453.036" x2="423.146" y2="452.687" stroke-linecap="round" style="stroke:rgb(103,76,26);stroke-width:1"/><line x1="423.146" y1="452.687" x2="433.108" y2="451.815" stroke-linecap="round" style="stroke:rgb(91,73,31);stroke-width:1"/><line x1="433.108" y1="451.815" x2="443.07" y2="450.943" stroke-linecap="round" style="stroke:rgb(91,73,31);stroke-width:1"/><line x1="443.07" y1="450.943" x2="450.95" y2="444.786" stroke-linecap="round" style="stroke:rgb(92,78,26);stroke-width:1"/><line x1="443.07" y1="450.943" x2="447.765" y2="459.772" stroke-linecap="round" style="stroke:rgb(92,78,26);stroke-width:1"/><line x1="447.765" y1="459.772" x2="452.46" y2="468.601" stroke-linecap="round" style="stroke:rgb(90,215,0);stroke-width:2"/><line x1="452.46" y1="468.601" x2="449.872" y2="478.26" stroke-linecap="round" style="stroke:rgb(86,222,0);stroke-width:2 ...

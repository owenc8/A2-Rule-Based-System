# %% [markdown]
# <a href="https://colab.research.google.com/github/owenc8/A2-Rule-Based-System/blob/main/A2_IAT460.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install ColabTurtle
# Out:
# Collecting ColabTurtle
#   Downloading ColabTurtle-2.1.0.tar.gz (6.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ColabTurtle
#   Building wheel for ColabTurtle (setup.py) ... done
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7642 sha256=a9b4fff19c6268f04f4869f1732a1b2abac4132ecb0ff1a95c200f4ffaa38f24
#   Stored in directory: /root/.cache/pip/wheels/f6/9e/81/137e7da25129474562d30f8660be599e5c8d79228cb747e5b9
# Successfully built ColabTurtle
# Installing collected packages: ColabTurtle
# Successfully installed ColabTurtle-2.1.0

# %%
import ColabTurtle.Turtle as t
from IPython.display import clear_output
import random

# %% [markdown]
# lab 3 L system code

# %%
def create_l_system(iterations, axiom, rules):
    """Generate L-System instructions based on axiom and rules."""

    result = axiom
    for _ in range(iterations):
        new_string = ""

        for char in result:
            new_string += rules.get(char, char)
        result = new_string
    return result

def draw_l_system(instructions, angle, distance):
    """Draw the L-System using turtle graphics.

    Parameters:
    - instructions: string of L-System commands
    - angle: turning angle in degrees
    - distance: forward movement distance
    """
    stack = []
    for cmd in instructions:
        if cmd == 'F':  # Move forward and draw
            t.forward(distance)
        elif cmd == 'f':  # Move forward without drawing
            t.penup()
            t.forward(distance)
            t.pendown()
        elif cmd == '+':  # Turn right
            t.right(angle)
        elif cmd == '-':  # Turn left
            t.left(angle)
        elif cmd == '[':  # Save current state
            stack.append((t.position(), t.heading()))
        elif cmd == ']':  # Restore previous state
            position, heading = stack.pop()
            t.penup()
            t.goto(position)
            t.setheading(heading)
            t.pendown()

def setup_turtle():
        t.initializeTurtle()
        t.hideturtle()
        t.speed(13)  # Fastest speed
        t.penup()
        t.goto(t.window_width() // 2, t.window_height()-100)  # Start position
        t.pendown()

# %%
# Plant parameters
plant_axiom = "X"
plant_rules = {
    "X": "F+[[X]-X]-F[-FX]+X",
    "F": "FF"
}
plant_iterations = 4
plant_angle = 25

# Generate and draw
setup_turtle()
t.pensize(1)
plant_instructions = create_l_system(plant_iterations, plant_axiom, plant_rules)
draw_l_system(plant_instructions, plant_angle, 10)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="450" x2="400.0" y2="440.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="440.0" x2="400.0" y2="430.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="430.0" x2="400.0" y2="420.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="420.0" x2="400.0" y2="410.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="410.0" x2="400.0" y2="400.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="400.0" x2="400.0" y2="390.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="390.0" x2="400.0" y2="380.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="380.0" x2="400.0" y2="370.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="370.0" x2="404.226" y2="360.937" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="404.226" y1="360.937" x2="408.452" y2="351.874" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="408.452" y1="351.874" x2="412.678" y2="342.811" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="412.678" y1="342.811" x2="416.904" y2="333.748" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="416.904" y1="333.748" x2="424.564" y2="327.32" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="424.564" y1="327.32" x2="432.224" y2="320.892" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="432.224" y1="320.892" x2="441.883" y2="318.304" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="441.883" y1="318.304" x2="451.542" y2="315.716" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="451.542" y1="315.716" x2="459.202" y2="309.288" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="432.224" y1="320.892" x2="439.884" y2="314.464" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="439.884" y1="314.464" x2="447.544" y2="308.036" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="447.544" y1="308.036" x2="451.77" y2="298.973" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="432.224" y1="320.892" x2="439.884" y2="314.464" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="439.884" y1="314.464" x2="447.544" y2="308.036" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="447.544" y1="308.036" x2="451.77" y2="298.973" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="451.77" y1="298.973" x2="455.996" y2="289.91" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="455.996" y1="289.91" x2="460.222" y2="280.847" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="460.222" y1="280.847" x2="464.448" y2="271.784" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="464.448" y1="271.784" x2="464.448" y2="261.784" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="447.544" y1="308.036" x2="457.203" y2="305.448" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="457.203" y1="305.448" x2="466.862" y2="302.86" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="466.862" y1="302.86" x2="474.522" y2="296.432" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="416.904" y1="333.748" x2="421.13" y2="324.685" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="421.13" y1="324.685" x2="425.356" y2="315.622" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="425.356" y1="315.622" x2="433.016" y2="309.194" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="433.016" y1="309.194" x2="440.676" y2="302.766" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="440.676" y1="302.766" x2="444.902" y2="293.703" strok ...

# %%
import random
# Your fractal tree parameters
tree_axiom = "X"  # Start with a single trunk
tree_rules = {
    "F": "F+F--F+F",
    "X": "F+[[X]-X]-F[-FX]+X"


}  # Basic branching rule
tree_iterations = 4
tree_angle = 90

#plant_axiom = "X"
# plant_rules = {
#     "X": "F+[[X]-X]-F[-FX]+X",
#     "F": "FF"
# }


# Generate and draw
setup_turtle()

red = 40
green = 40
blue = 255
t.pencolor(red,green,blue)
t.pensize(1)
tree_instructions = create_l_system(tree_iterations, tree_axiom, tree_rules)
for i in range(4):
    red+=10
    green+=10
    t.pencolor(red,green,blue)
    draw_l_system(tree_instructions, tree_angle, 10)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="450" x2="400.0" y2="440.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="400.0" y1="440.0" x2="410.0" y2="440.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="440.0" x2="400.0" y2="440.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="400.0" y1="440.0" x2="400.0" y2="430.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="400.0" y1="430.0" x2="410.0" y2="430.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="430.0" x2="410.0" y2="440.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="440.0" x2="410.0" y2="430.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="430.0" x2="420.0" y2="430.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="420.0" y1="430.0" x2="410.0" y2="430.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="430.0" x2="410.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="420.0" x2="410.0" y2="430.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="430.0" x2="400.0" y2="430.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="400.0" y1="430.0" x2="400.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="400.0" y1="420.0" x2="410.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="420.0" x2="400.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="400.0" y1="420.0" x2="400.0" y2="410.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="400.0" y1="410.0" x2="410.0" y2="410.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="410.0" x2="410.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="420.0" x2="410.0" y2="410.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="410.0" x2="420.0" y2="410.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="420.0" y1="410.0" x2="420.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="420.0" y1="420.0" x2="410.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="420.0" x2="420.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="420.0" y1="420.0" x2="420.0" y2="430.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="420.0" y1="430.0" x2="420.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="420.0" y1="420.0" x2="430.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="430.0" y1="420.0" x2="420.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="420.0" y1="420.0" x2="420.0" y2="410.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="420.0" y1="410.0" x2="430.0" y2="410.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="430.0" y1="410.0" x2="430.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="430.0" y1="420.0" x2="430.0" y2="410.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="430.0" y1="410.0" x2="440.0" y2="410.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="440.0" y1="410.0" x2="430.0" y2="410.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="430.0" y1="410.0" x2="430.0" y2="400.0" stroke-linecap="rou ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-388768c7aa18> in <cell line: 0>()
#      31     green+=10
#      32     t.pencolor(red,green,blue)
# ---> 33     draw_l_system(tree_instructions, tree_angle, 10)
#      34
#
# <ipython-input-23-712db2c00678> in draw_l_system(instructions, angle, distance)
#      38             t.pencolor((40+X,40+X,255-X))
#      39             t.penup()
# ---> 40             t.goto(position)
#      41             t.setheading(heading)
#      42             t.pendown()
#
# /usr/local/lib/python3.11/dist-packages/ColabTurtle/Turtle.py in goto(x, y)
#     323         raise ValueError('new y position must be a number.')
#     324     if y < 0:
# --> 325         raise ValueError('new y position must be non-negative.')
#     326     _moveToNewPosition((x, y))
#     327
#
# ValueError: new y position must be non-negative.

# %%
# axiom = FX
# X -> X+YF+
# Y -> -FX-Y
# angle = 90

# Your fractal tree parameters
tree_axiom = "FX"  # Start with a single trunk
tree_rules = {
    "Y": "-FX-Y",
    "X": "X+YF+"


}  # Basic branching rule
tree_iterations = 9
tree_angle = 90

#plant_axiom = "X"
# plant_rules = {
#     "X": "F+[[X]-X]-F[-FX]+X",
#     "F": "FF"
# }

size=4
# Generate and draw

setup_turtle()
def changeColour():
  red = red*1.1
  green = green*1.1
  t.pencolor(red,green,blue)


t.pensize(size)

# initial_color = (40, 40, 255)
red = 40
green = 40
blue = 255
t.pencolor(red,green,blue)
for i in range(3):
  size-=1
  t.pensize(size)
  light = 10
  newRed = red+light
  newGreen = green+light
  t.pencolor(newRed,newGreen,255)

  tree_instructions = create_l_system(tree_iterations, tree_axiom, tree_rules)
  draw_l_system(tree_instructions, tree_angle, 10)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="400" x2="400.0" y2="390.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="400.0" y1="390.0" x2="410.0" y2="390.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="410.0" y1="390.0" x2="410.0" y2="400.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="410.0" y1="400.0" x2="420.0" y2="400.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="420.0" y1="400.0" x2="420.0" y2="410.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="420.0" y1="410.0" x2="410.0" y2="410.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="410.0" y1="410.0" x2="410.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="410.0" y1="420.0" x2="420.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="420.0" y1="420.0" x2="420.0" y2="430.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="420.0" y1="430.0" x2="410.0" y2="430.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="410.0" y1="430.0" x2="410.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="410.0" y1="420.0" x2="400.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="400.0" y1="420.0" x2="400.0" y2="430.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="400.0" y1="430.0" x2="390.0" y2="430.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="390.0" y1="430.0" x2="390.0" y2="440.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="390.0" y1="440.0" x2="400.0" y2="440.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="400.0" y1="440.0" x2="400.0" y2="450.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="400.0" y1="450.0" x2="390.0" y2="450.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="390.0" y1="450.0" x2="390.0" y2="440.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="390.0" y1="440.0" x2="380.0" y2="440.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="380.0" y1="440.0" x2="380.0" y2="430.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="380.0" y1="430.0" x2="390.0" y2="430.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="390.0" y1="430.0" x2="390.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="390.0" y1="420.0" x2="380.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="380.0" y1="420.0" x2="380.0" y2="430.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="380.0" y1="430.0" x2="370.0" y2="430.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="370.0" y1="430.0" x2="370.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="370.0" y1="420.0" x2="360.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="360.0" y1="420.0" x2="360.0" y2="430.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="360.0" y1="430.0" x2="350.0" y2="430.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="350.0" y1="430.0" x2="350.0" y2="440.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="350.0" y1="440.0" x2="360.0" y2="440.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="360.0" y1="440.0" x2="360.0" y2="450.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:3"/><line x1="360.0" y1="450.0" x2="350.0" y2="450.0" stroke-linecap="rou ...

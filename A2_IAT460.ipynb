# %% [markdown]
# <a href="https://colab.research.google.com/github/owenc8/A2-Rule-Based-System/blob/main/A2_IAT460.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install ColabTurtle
# Out:
# Collecting ColabTurtle
#   Downloading ColabTurtle-2.1.0.tar.gz (6.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ColabTurtle
#   Building wheel for ColabTurtle (setup.py) ... done
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7642 sha256=41ab538289bb8804165fca16e87b56ee4b2d4bc899241290962e9988be026ebc
#   Stored in directory: /root/.cache/pip/wheels/f6/9e/81/137e7da25129474562d30f8660be599e5c8d79228cb747e5b9
# Successfully built ColabTurtle
# Installing collected packages: ColabTurtle
# Successfully installed ColabTurtle-2.1.0

# %%
import ColabTurtle.Turtle as t
from IPython.display import clear_output
import random

# %% [markdown]
# lab 3 L system code

# %%
def create_l_system(iterations, axiom, rules):

    result = axiom
    for _ in range(iterations):
        new_string = ""

        for char in result:
            new_string += rules.get(char, char)
        result = new_string
    return result

def draw_l_system(instructions, angle, distance,branchWidth):

    stack = []
    for cmd in instructions:
        if cmd == 'F':  # Move forward and draw
            t.pensize(branchWidth)
            t.forward(distance)
            if branchWidth > 1:
                branchWidth -= 1
        elif cmd == 'f':  # Move forward without drawing
            t.penup()
            t.forward(distance)
            t.pendown()
        elif cmd == '+':  # Turn right
            t.right(angle)
        elif cmd == '-':  # Turn left
            t.left(angle)
        elif cmd == '[':  # Save current state
            stack.append((t.position(), t.heading()))
        elif cmd == ']':  # Restore previous state
            position, heading = stack.pop()
            t.penup()
            t.goto(position)
            t.setheading(heading)
            t.pendown()

def setup_turtle():
        t.initializeTurtle()
        t.hideturtle()
        t.speed(13)  # Fastest speed
        t.penup()
        t.goto(t.window_width() // 2, t.window_height()-100)  # Start position
        t.pendown()

def setup_turtle_bottom():
        t.initializeTurtle()
        t.hideturtle()
        t.speed(13)  # Fastest speed
        t.penup()
        t.goto(t.window_width() // 2, t.window_height())  # Start position
        t.pendown()



def draw_l_system_randAngle(instructions, distance,branchWidth):

    stack = []
    for cmd in instructions:
        if cmd == 'F':  # Move forward and draw
            t.pensize(branchWidth)
            t.pencolor(random.randint(90,110),random.randint(60,80),random.randint(25,35))
            t.forward(distance)
            if branchWidth > 1:
                branchWidth -=1
            elif branchWidth ==1:
              branchWidth = 1
        elif cmd == 'f':  # Move forward without drawing
            t.penup()
            t.forward(distance)
            t.pendown()
        elif cmd == '+':  # Turn right
            t.right(random.randint(15,45))
        elif cmd == '-':  # Turn left
            t.left(random.randint(15,45))
        elif cmd == '[':  # Save current state
            stack.append((t.position(), t.heading()))
        elif cmd == ']':  # Restore previous state
            position, heading = stack.pop()
            t.penup()
            t.goto(position)
            t.setheading(heading)
            t.pendown()
        elif cmd == 'L': #leaf
          t.forward(distance)
          t.pensize(2)
          t.pencolor(random.randint(30,100),random.randint(200,240),0)

# %% [markdown]
# # **Trees**

# %% [markdown]
# In the function "create_Tree()" there are 4 parameters the user can change.
#
# In order they are:
# 1.   Branch length(length of each branch segment)
# 2.   Trunk thickness(starting thickness of trunk)
# 3.   Iterations(overall branch length)
# 4.   Density(number of trees drawn on top of each other to add more branches)

# %%
# Plant parameters
tree_axiom = "X"
possible_rules = [
    {
        "X": "F+[[X]-X]-FL[-FX]+XL",
        "F": "FF",
        "L" :"[L[++L][--L]], L"
    },
    {
        "X": "F+[[X]-X]-FL[-FX]++XL",
        "F": "FF",
        "L" :"[L[++L][--L]], L"
    },
    {
        "X": "F+[[X]--X]-FL[-FX]+XL",
        "F": "FF",
        "L" :"[L[++L][--L]], L"
    },
    {
        "X": "F+[[+X]-X]-FL[--FX]+XL",
        "F": "FF",
        "L" :"[L[++L][--L]], L"
    },
     {
        "X": "F++[[-X]-X]-FL[-FX]+XL",
        "F": "FF",
        "L" :"[L[++L][--L]], L"
    }
]
def randomize_rules():
  return random.choice(possible_rules)

chosen_rules = randomize_rules()
print("Branching pattern:")
print(chosen_rules)

def reset_turtle():
  t.penup()
  t.goto(t.window_width() // 2, t.window_height())
  t.pendown()
  t.setheading(270)
# Generate and draw
setup_turtle_bottom()

def create_Tree(branchLen,trunkThickness,plant_iterations,density):
  for i in range(density):
    tree_rules = randomize_rules()
    plant_instructions = create_l_system(plant_iterations, tree_axiom, tree_rules)
    draw_l_system_randAngle(plant_instructions, branchLen,trunkThickness)
    reset_turtle()

create_Tree(10,15,4,4)

# %%
create_Tree(10,15,4,4)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="500" x2="400.0" y2="490.0" stroke-linecap="round" style="stroke:rgb(104,74,31);stroke-width:15"/><line x1="400.0" y1="490.0" x2="400.0" y2="480.0" stroke-linecap="round" style="stroke:rgb(98,80,30);stroke-width:14"/><line x1="400.0" y1="480.0" x2="400.0" y2="470.0" stroke-linecap="round" style="stroke:rgb(103,78,26);stroke-width:13"/><line x1="400.0" y1="470.0" x2="400.0" y2="460.0" stroke-linecap="round" style="stroke:rgb(109,60,26);stroke-width:12"/><line x1="400.0" y1="460.0" x2="400.0" y2="450.0" stroke-linecap="round" style="stroke:rgb(90,74,29);stroke-width:11"/><line x1="400.0" y1="450.0" x2="400.0" y2="440.0" stroke-linecap="round" style="stroke:rgb(102,77,34);stroke-width:10"/><line x1="400.0" y1="440.0" x2="400.0" y2="430.0" stroke-linecap="round" style="stroke:rgb(104,64,31);stroke-width:9"/><line x1="400.0" y1="430.0" x2="400.0" y2="420.0" stroke-linecap="round" style="stroke:rgb(101,72,35);stroke-width:8"/><line x1="400.0" y1="420.0" x2="406.293" y2="412.229" stroke-linecap="round" style="stroke:rgb(110,74,28);stroke-width:7"/><line x1="406.293" y1="412.229" x2="412.586" y2="404.458" stroke-linecap="round" style="stroke:rgb(90,69,28);stroke-width:6"/><line x1="412.586" y1="404.458" x2="418.879" y2="396.687" stroke-linecap="round" style="stroke:rgb(108,62,32);stroke-width:5"/><line x1="418.879" y1="396.687" x2="425.172" y2="388.916" stroke-linecap="round" style="stroke:rgb(105,68,26);stroke-width:4"/><line x1="425.172" y1="388.916" x2="434.508" y2="385.332" stroke-linecap="round" style="stroke:rgb(109,80,30);stroke-width:3"/><line x1="434.508" y1="385.332" x2="443.844" y2="381.748" stroke-linecap="round" style="stroke:rgb(97,77,32);stroke-width:2"/><line x1="443.844" y1="381.748" x2="453.721" y2="383.312" stroke-linecap="round" style="stroke:rgb(97,73,34);stroke-width:1"/><line x1="453.721" y1="383.312" x2="462.784" y2="387.538" stroke-linecap="round" style="stroke:rgb(95,65,29);stroke-width:1"/><line x1="462.784" y1="387.538" x2="471.847" y2="391.764" stroke-linecap="round" style="stroke:rgb(95,65,29);stroke-width:1"/><line x1="471.847" y1="391.764" x2="481.792" y2="392.809" stroke-linecap="round" style="stroke:rgb(105,76,30);stroke-width:1"/><line x1="471.847" y1="391.764" x2="478.004" y2="399.644" stroke-linecap="round" style="stroke:rgb(105,76,30);stroke-width:1"/><line x1="443.844" y1="381.748" x2="453.747" y2="380.356" stroke-linecap="round" style="stroke:rgb(99,61,31);stroke-width:1"/><line x1="453.747" y1="380.356" x2="463.258" y2="383.446" stroke-linecap="round" style="stroke:rgb(99,63,25);stroke-width:1"/><line x1="463.258" y1="383.446" x2="472.769" y2="386.536" stroke-linecap="round" style="stroke:rgb(99,63,25);stroke-width:1"/><line x1="472.769" y1="386.536" x2="482.646" y2="384.972" stroke-linecap="round" style="stroke:rgb(95,75,34);stroke-width:1"/><line x1="472.769" y1="386.536" x2="477.617" y2="395.282" stroke-linecap="round" style="stroke:rgb(95,75,34);stroke-width:1"/><line x1="443.844" y1="381.748" x2="453.806" y2="380.876" stroke-linecap="round" style="stroke:rgb(91,69,27);stroke-width:1"/><line x1="453.806" y1="380.876" x2="463.768" y2="380.004" stroke-linecap="round" style="stroke:rgb(110,60,32);stroke-width:1"/><line x1="463.768" y1="380.004" x2="473.73" y2="379.132" stroke-linecap="round" style="stroke:rgb(110,60,32);stroke-width:1"/><line x1="473.73" y1="379.132" x2="482.117" y2="384.578" stroke-linecap="round" style="stroke:rgb(54,210,0);stroke-width:2"/><line x1="473.73" y1="379.132" x2="477.476" y2="369.86" stroke-linecap="round" style="stroke:rgb(96,223,0);stroke-width:2"/><line x1="463.768" y1="380.004" x2="473.73" y2="379.132" stroke-linecap="round" style="stroke:rgb(82,217,0);stroke-width:2"/><line x1="473.73" y1="379.132" x2="480.55" y2="371.818" stroke-linecap="round" style="stroke:rgb(102,72,25);stroke-width:1"/><line x1="480.55" y1="371.818" x2="487.37" y2="364.504" stroke-linecap="round" style="stroke:rgb(109,62,30);stroke-width:1"/><line x1="487.37" y ...

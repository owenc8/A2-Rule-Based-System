# %% [markdown]
# <a href="https://colab.research.google.com/github/owenc8/A2-Rule-Based-System/blob/main/A2_IAT460.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install ColabTurtle
# Out:
# Collecting ColabTurtle
#   Downloading ColabTurtle-2.1.0.tar.gz (6.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ColabTurtle
#   Building wheel for ColabTurtle (setup.py) ... done
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7642 sha256=116697fa180f69ba030f55289b3e0ffaa3fd467cef3e8dc7bdbbdd0946f2e176
#   Stored in directory: /root/.cache/pip/wheels/f6/9e/81/137e7da25129474562d30f8660be599e5c8d79228cb747e5b9
# Successfully built ColabTurtle
# Installing collected packages: ColabTurtle
# Successfully installed ColabTurtle-2.1.0

# %%
import ColabTurtle.Turtle as t
from IPython.display import clear_output
import random

# %% [markdown]
# lab 3 L system code

# %%
def create_l_system(iterations, axiom, rules,branchWidth):
    """Generate L-System instructions based on axiom and rules."""

    result = axiom
    for _ in range(iterations):
        new_string = ""
        # if branchWidth<= 1:
        #   branchWidth = 1
        # else:
        #   branchWidth-=1
        #   t.pensize(branchWidth)

        branchWidth-=1
        t.pensize(branchWidth)

        for char in result:
            new_string += rules.get(char, char)
        result = new_string
    return result

def turtle_bounds():
  if t.xcor() > t.window_width() or t.xcor() < 0 or t.ycor() > t.window_height() or t.ycor() < 0:
    return True
  return False

def draw_l_system(instructions, angle, distance):
    """Draw the L-System using turtle graphics.

    Parameters:
    - instructions: string of L-System commands
    - angle: turning angle in degrees
    - distance: forward movement distance
    """

    stack = []
    for cmd in instructions:
        if cmd == 'F':  # Move forward and draw
            t.forward(distance)
        elif cmd == 'f':  # Move forward without drawing
            t.penup()
            t.forward(distance)
            t.pendown()
        elif cmd == '+':  # Turn right
            t.right(angle)
        elif cmd == '-':  # Turn left
            t.left(angle)
        elif cmd == '[':  # Save current state
            stack.append((t.position(), t.heading()))
        elif cmd == ']':  # Restore previous state
            position, heading = stack.pop()
            t.penup()
            t.goto(position)
            t.setheading(heading)
            t.pendown()

def setup_turtle():
        t.initializeTurtle()
        t.hideturtle()
        t.speed(13)  # Fastest speed
        t.penup()
        t.goto(t.window_width() // 2, t.window_height()-100)  # Start position
        t.pendown()

def setup_turtle_bottom():
        t.initializeTurtle()
        t.hideturtle()
        t.speed(13)  # Fastest speed
        t.penup()
        t.goto(t.window_width() // 2, t.window_height())  # Start position
        t.pendown()



def draw_l_system_randAngle(instructions, distance):

    stack = []
    for cmd in instructions:
        if cmd == 'F':  # Move forward and draw
            t.forward(distance)
        elif cmd == 'f':  # Move forward without drawing
            t.penup()
            t.forward(distance)
            t.pendown()
        elif cmd == '+':  # Turn right
            t.right(random.randint(15,45))
        elif cmd == '-':  # Turn left
            t.left(random.randint(15,45))
        elif cmd == '[':  # Save current state
            stack.append((t.position(), t.heading()))
        elif cmd == ']':  # Restore previous state
            position, heading = stack.pop()
            t.penup()
            t.goto(position)
            t.setheading(heading)
            t.pendown()

# %% [markdown]
# Trees

# %%
# # axiom = FX
# # X -> X+YF+
# # Y -> -FX-Y
# # angle = 90
# import random

# # cool pattern
# # tree_axiom = "FXX"
# # tree_rules = {
# #     "Y": "-FX-Y",
# #     "X": "X+YF+"
# # }

# #geometric pattern
# # tree_axiom = "X"
# # tree_rules = {
# #     "F": "F+F--F+F",
# #     "X": "F+[[X]-X]-F[-FX]+X"


# # }

# #TREE
# #F :FF, F
# #X : F+-+[[X[[L][+L][-L]]]--X[[L][++L][--L]]]-F[-F[[L][+L][-L]]]+X[[L][+L][-L]]
# #L :[L[++L][--L]], L
# # possible_axioms = ["FXY", "FX", "FXX", "FFX"]
# # possible_rules = [
# #     {
# #         "Y": "-FX-Y",
# #         "X": "X+YF+"
# #     },
# #     {
# #         "Y": "+FX+Y",
# #         "X": "X-YF-"
# #     },
# #     {
# #         "Y": "FX-Y",
# #         "X": "X+YF"
# #     },
# #     {
# #         "Y": "FX+Y",
# #         "X": "X-YF"
# #     }
# # ]

# possible_axioms = ["FF,F"]
# possible_rules = [
#     {
#         "X" : "F+-+[[X[[L][+L][-L]]]--X[[L][++L][--L]]]-F[-F[[L][+L][-L]]]+X[[L][+L][-L]]",
#         "L" :"[L[++L][--L]], L"
#     }
# ]
# tree_axiom = random.choice(possible_axioms)  # Randomly choose an axiom
# tree_rules = random.choice(possible_rules)

# print("Selected Axiom:", tree_axiom)
# print("Selected Rules:", tree_rules)

#  # Basic branching rule
# tree_iterations = 6
# tree_angle = random.randint(60,90)

# size=2
# # Generate and draw

# setup_turtle()
# def changeColour():
#   red = random.randint(40,120)
#   green = random.randint(150,255)
#   blue = random.randint(220,255)
#   t.pencolor(red,green,blue)


# t.pensize(size)

# # initial_color = (40, 40, 255)
# red = 40
# green = 40
# blue = 255
# t.pencolor(red,green,blue)
# for i in range(3):

#   t.pensize(size)
#   changeColour()

#   tree_instructions = create_l_system(tree_iterations, tree_axiom, tree_rules)
#   draw_l_system(tree_instructions,tree_angle, 7)

# %%
# import random


# possible_axioms = ["F", "FF", "FFF"]
# possible_rules = [
#     {
#         "F": "F[+X][-X]FX",
#        "X":"[F[++F][--F]]"

#     },
#     {
#         "F": "F[+X]FX",
#        "X":"[F[++F][--F]]"


#     },
#     {
#         "F": "F[-X]FX",
#        "X":"[F[++F][--F]]"


#     },
#     {
#         "F": "F[+X][-X]",
#        "X":"[F[++F][--F]]"


#     },
#     {
#         "F": "F[+X][-X]X",
#        "X":"[F[++F][--F]]"


#     }
# ]




# tree_axiom = random.choice(possible_axioms)
# tree_rules = random.choice(possible_rules)
# print("Selected Axiom:", tree_axiom)
# print("Selected Rules:", tree_rules)
#  # Basic branching rule
# tree_iterations = 6



# # Generate and draw

# setup_turtle_bottom()

# def changeColour():
#   red = random.randint(40,120)
#   green = random.randint(150,255)
#   blue = random.randint(220,255)
#   t.pencolor(red,green,blue)


# t.pensize(1)



# tree_instructions = create_l_system(tree_iterations, tree_axiom, tree_rules)
# draw_l_system_randAngle(tree_instructions, 8)

# %%
# Plant parameters
tree_axiom = "X"
possible_rules = [
    {
        "X": "F+[[X]-X]-F[-FX]+X",
        "F": "FF"
    },
    {
        "X": "F+[[X]-X]-F[-FX]++X",
        "F": "FF"
    },
    {
        "X": "F+[[X]--X]-F[-FX]+X",
        "F": "FF"
    },
    {
        "X": "F+[[+X]-X]-F[--FX]+X",
        "F": "FF"
    }
]
def randomize_rules():
  return random.choice(possible_rules)

plant_iterations = 4

def draw_leaf(size, colour):
    t.begin_fill()
    t.fillcolor(colour)
    t.circle(size)
    t.end_fill()
def reset_turtle():
  t.penup()
  t.goto(t.window_width() // 2, t.window_height())  # Start position
  t.pendown()
  t.setheading(270)
# Generate and draw
setup_turtle_bottom()

for i in range(3):
  # t.pensize(1)
  tree_rules = randomize_rules()
  plant_instructions = create_l_system(plant_iterations, tree_axiom, tree_rules,5)
  draw_l_system_randAngle(plant_instructions,  10)
  reset_turtle()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="500" x2="400.0" y2="490.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="490.0" x2="400.0" y2="480.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="480.0" x2="400.0" y2="470.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="470.0" x2="400.0" y2="460.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="460.0" x2="400.0" y2="450.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="450.0" x2="400.0" y2="440.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="440.0" x2="400.0" y2="430.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="430.0" x2="400.0" y2="420.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="420.0" x2="402.924" y2="410.437" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="402.924" y1="410.437" x2="405.848" y2="400.874" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="405.848" y1="400.874" x2="408.772" y2="391.311" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="408.772" y1="391.311" x2="411.696" y2="381.748" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="411.696" y1="381.748" x2="420.083" y2="376.302" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="420.083" y1="376.302" x2="428.47" y2="370.856" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="428.47" y1="370.856" x2="438.415" y2="369.811" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="438.415" y1="369.811" x2="446.802" y2="364.365" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="446.802" y1="364.365" x2="449.39" y2="354.706" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="428.47" y1="370.856" x2="434.898" y2="363.196" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="434.898" y1="363.196" x2="440.49" y2="354.906" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="440.49" y1="354.906" x2="440.315" y2="344.908" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="428.47" y1="370.856" x2="435.417" y2="363.663" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="435.417" y1="363.663" x2="442.364" y2="356.47" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="442.364" y1="356.47" x2="447.059" y2="347.641" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="447.059" y1="347.641" x2="451.754" y2="338.812" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="451.754" y1="338.812" x2="456.449" y2="329.983" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="456.449" y1="329.983" x2="460.833" y2="320.995" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="460.833" y1="320.995" x2="460.658" y2="310.997" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="442.364" y1="356.47" x2="452.35" y2="355.947" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="452.35" y1="355.947" x2="462.166" y2="354.039" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="462.166" y1="354.039" x2="470.826" y2="349.039" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="411.696" y1="381.748" x2="414.284" y2="372.089" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="414.284" y1="372.089" x2="416.872" y2="362.43" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="416.872" y1="362.43" x2="424.532" y2="356.002" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="424.532" y1="356.002" x2="433.987" y2="352.746" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="433.987" y1="352.746" x2="438.682" y2="343.917" stroke-l ...

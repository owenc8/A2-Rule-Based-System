# %% [markdown]
# <a href="https://colab.research.google.com/github/owenc8/A2-Rule-Based-System/blob/main/A2_IAT460.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install ColabTurtle
# Out:
# Collecting ColabTurtle
#   Downloading ColabTurtle-2.1.0.tar.gz (6.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ColabTurtle
#   Building wheel for ColabTurtle (setup.py) ... done
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7642 sha256=210aa2b20eb10c7dadc47575108a74e547cea72afbffea721c8799edd89a6aba
#   Stored in directory: /root/.cache/pip/wheels/f6/9e/81/137e7da25129474562d30f8660be599e5c8d79228cb747e5b9
# Successfully built ColabTurtle
# Installing collected packages: ColabTurtle
# Successfully installed ColabTurtle-2.1.0

# %%
import ColabTurtle.Turtle as t
from IPython.display import clear_output
import random

# %% [markdown]
# lab 3 L system code

# %%
def create_l_system(iterations, axiom, rules):
    """Generate L-System instructions based on axiom and rules."""

    result = axiom
    for _ in range(iterations):
        new_string = ""

        for char in result:
            new_string += rules.get(char, char)
        result = new_string
    return result

def turtle_bounds():
  if t.xcor() > t.window_width() or t.xcor() < 0 or t.ycor() > t.window_height() or t.ycor() < 0:
    return True
  return False

def draw_l_system(instructions, angle, distance):
    """Draw the L-System using turtle graphics.

    Parameters:
    - instructions: string of L-System commands
    - angle: turning angle in degrees
    - distance: forward movement distance
    """

    stack = []
    for cmd in instructions:
        if cmd == 'F':  # Move forward and draw
            t.forward(distance)
        elif cmd == 'f':  # Move forward without drawing
            t.penup()
            t.forward(distance)
            t.pendown()
        elif cmd == '+':  # Turn right
            t.right(angle)
        elif cmd == '-':  # Turn left
            t.left(angle)
        elif cmd == '[':  # Save current state
            stack.append((t.position(), t.heading()))
        elif cmd == ']':  # Restore previous state
            position, heading = stack.pop()
            t.penup()
            t.goto(position)
            t.setheading(heading)
            t.pendown()

def setup_turtle():
        t.initializeTurtle()
        t.hideturtle()
        t.speed(13)  # Fastest speed
        t.penup()
        t.goto(t.window_width() // 2, t.window_height()-100)  # Start position
        t.pendown()

def setup_turtle_bottom():
        t.initializeTurtle()
        t.hideturtle()
        t.speed(13)  # Fastest speed
        t.penup()
        t.goto(t.window_width() // 2, t.window_height())  # Start position
        t.pendown()



def draw_l_system_randAngle(instructions, distance):

    stack = []
    for cmd in instructions:
        if cmd == 'F':  # Move forward and draw
            t.forward(distance)
        elif cmd == 'f':  # Move forward without drawing
            t.penup()
            t.forward(distance)
            t.pendown()
        elif cmd == '+':  # Turn right
            t.right(random.randint(15,45))
        elif cmd == '-':  # Turn left
            t.left(random.randint(15,45))
        elif cmd == '[':  # Save current state
            stack.append((t.position(), t.heading()))
        elif cmd == ']':  # Restore previous state
            position, heading = stack.pop()
            t.penup()
            t.goto(position)
            t.setheading(heading)
            t.pendown()

# %% [markdown]
# Trees

# %%
# axiom = FX
# X -> X+YF+
# Y -> -FX-Y
# angle = 90
import random

# cool pattern
# tree_axiom = "FXX"
# tree_rules = {
#     "Y": "-FX-Y",
#     "X": "X+YF+"
# }

#geometric pattern
# tree_axiom = "X"
# tree_rules = {
#     "F": "F+F--F+F",
#     "X": "F+[[X]-X]-F[-FX]+X"


# }

#TREE
#F :FF, F
#X : F+-+[[X[[L][+L][-L]]]--X[[L][++L][--L]]]-F[-F[[L][+L][-L]]]+X[[L][+L][-L]]
#L :[L[++L][--L]], L
# possible_axioms = ["FXY", "FX", "FXX", "FFX"]
# possible_rules = [
#     {
#         "Y": "-FX-Y",
#         "X": "X+YF+"
#     },
#     {
#         "Y": "+FX+Y",
#         "X": "X-YF-"
#     },
#     {
#         "Y": "FX-Y",
#         "X": "X+YF"
#     },
#     {
#         "Y": "FX+Y",
#         "X": "X-YF"
#     }
# ]

possible_axioms = ["FF,F"]
possible_rules = [
    {
        "X" : "F+-+[[X[[L][+L][-L]]]--X[[L][++L][--L]]]-F[-F[[L][+L][-L]]]+X[[L][+L][-L]]",
        "L" :"[L[++L][--L]], L"
    }
]
tree_axiom = random.choice(possible_axioms)  # Randomly choose an axiom
tree_rules = random.choice(possible_rules)

print("Selected Axiom:", tree_axiom)
print("Selected Rules:", tree_rules)

 # Basic branching rule
tree_iterations = 6
tree_angle = random.randint(60,90)

size=2
# Generate and draw

setup_turtle()
def changeColour():
  red = random.randint(40,120)
  green = random.randint(150,255)
  blue = random.randint(220,255)
  t.pencolor(red,green,blue)


t.pensize(size)

# initial_color = (40, 40, 255)
red = 40
green = 40
blue = 255
t.pencolor(red,green,blue)
for i in range(3):

  t.pensize(size)
  changeColour()

  tree_instructions = create_l_system(tree_iterations, tree_axiom, tree_rules)
  draw_l_system(tree_instructions,tree_angle, 7)
# Out:
# Selected Axiom: FF,F
# Selected Rules: {'X': 'F+-+[[X[[L][+L][-L]]]--X[[L][++L][--L]]]-F[-F[[L][+L][-L]]]+X[[L][+L][-L]]', 'L': '[L[++L][--L]], L'}
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="400" x2="400.0" y2="393.0" stroke-linecap="round" style="stroke:rgb(110,206,232);stroke-width:2"/><line x1="400.0" y1="393.0" x2="400.0" y2="386.0" stroke-linecap="round" style="stroke:rgb(110,206,232);stroke-width:2"/><line x1="400.0" y1="386.0" x2="400.0" y2="379.0" stroke-linecap="round" style="stroke:rgb(110,206,232);stroke-width:2"/><line x1="400.0" y1="379.0" x2="400.0" y2="372.0" stroke-linecap="round" style="stroke:rgb(79,232,246);stroke-width:2"/><line x1="400.0" y1="372.0" x2="400.0" y2="365.0" stroke-linecap="round" style="stroke:rgb(79,232,246);stroke-width:2"/><line x1="400.0" y1="365.0" x2="400.0" y2="358.0" stroke-linecap="round" style="stroke:rgb(79,232,246);stroke-width:2"/><line x1="400.0" y1="358.0" x2="400.0" y2="351.0" stroke-linecap="round" style="stroke:rgb(77,244,236);stroke-width:2"/><line x1="400.0" y1="351.0" x2="400.0" y2="344.0" stroke-linecap="round" style="stroke:rgb(77,244,236);stroke-width:2"/><line x1="400.0" y1="344.0" x2="400.0" y2="337.0" stroke-linecap="round" style="stroke:rgb(77,244,236);stroke-width:2"/>
#         <g visibility=hidden transform="rotate(360,400.0,337.0) translate(382.0, 319.0)">
# <path style=" stroke:none;fill-rule:evenodd;fill:rgb(77,244,236);fill-opacity:1;" d="M 18.214844 0.632812 C 16.109375 1.800781 15.011719 4.074219 15.074219 7.132812 L 15.085938 7.652344 L 14.785156 7.496094 C 13.476562 6.824219 11.957031 6.671875 10.40625 7.066406 C 8.46875 7.550781 6.515625 9.15625 4.394531 11.992188 C 3.0625 13.777344 2.679688 14.636719 3.042969 15.027344 L 3.15625 15.152344 L 3.519531 15.152344 C 4.238281 15.152344 4.828125 14.886719 8.1875 13.039062 C 9.386719 12.378906 10.371094 11.839844 10.378906 11.839844 C 10.386719 11.839844 10.355469 11.929688 10.304688 12.035156 C 9.832031 13.09375 9.257812 14.820312 8.96875 16.078125 C 7.914062 20.652344 8.617188 24.53125 11.070312 27.660156 C 11.351562 28.015625 11.363281 27.914062 10.972656 28.382812 C 8.925781 30.84375 7.945312 33.28125 8.238281 35.1875 C 8.289062 35.527344 8.28125 35.523438 8.917969 35.523438 C 10.941406 35.523438 13.074219 34.207031 15.136719 31.6875 C 15.359375 31.417969 15.328125 31.425781 15.5625 31.574219 C 16.292969 32.042969 18.023438 32.964844 18.175781 32.964844 C 18.335938 32.964844 19.941406 32.210938 20.828125 31.71875 C 20.996094 31.625 21.136719 31.554688 21.136719 31.558594 C 21.203125 31.664062 21.898438 32.414062 22.222656 32.730469 C 23.835938 34.300781 25.5625 35.132812 27.582031 35.300781 C 27.90625 35.328125 27.9375 35.308594 28.007812 34.984375 C 28.382812 33.242188 27.625 30.925781 25.863281 28.425781 L 25.542969 27.96875 L 25.699219 27.785156 C 28.945312 23.960938 29.132812 18.699219 26.257812 11.96875 L 26.207031 11.84375 L 27.945312 12.703125 C 31.53125 14.476562 32.316406 14.800781 33.03125 14.800781 C 33.976562 14.800781 33.78125 13.9375 32.472656 12.292969 C 28.519531 7.355469 25.394531 5.925781 21.921875 7.472656 L 21.558594 7.636719 L 21.578125 7.542969 C 21.699219 6.992188 21.761719 5.742188 21.699219 5.164062 C 21.496094 3.296875 20.664062 1.964844 19.003906 0.855469 C 18.480469 0.503906 18.457031 0.5 18.214844 0.632812"/>
# </g>
#       </svg>

# %%
import random


possible_axioms = ["F", "FF", "FFF"]
possible_rules = [
    {
        "F": "F[+X][-X]FX",
       "X":"[F[++F][--F]]"

    },
    {
        "F": "F[+X]FX",
       "X":"[F[++F][--F]]"


    },
    {
        "F": "F[-X]FX",
       "X":"[F[++F][--F]]"


    },
    {
        "F": "F[+X][-X]",
       "X":"[F[++F][--F]]"


    },
    {
        "F": "F[+X][-X]X",
       "X":"[F[++F][--F]]"


    }
]




tree_axiom = random.choice(possible_axioms)
tree_rules = random.choice(possible_rules)
print("Selected Axiom:", tree_axiom)
print("Selected Rules:", tree_rules)
 # Basic branching rule
tree_iterations = 6



# Generate and draw

setup_turtle_bottom()

def changeColour():
  red = random.randint(40,120)
  green = random.randint(150,255)
  blue = random.randint(220,255)
  t.pencolor(red,green,blue)


t.pensize(1)



tree_instructions = create_l_system(tree_iterations, tree_axiom, tree_rules)
draw_l_system_randAngle(tree_instructions, 8)
# Out:
# Selected Axiom: FFF
# Selected Rules: {'F': 'F[-X]FX', 'X': '[F[++F][--F]]'}
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="500" x2="400.0" y2="492.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="492.0" x2="400.0" y2="484.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="484.0" x2="396.493" y2="476.81" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="396.493" y1="476.81" x2="399.619" y2="469.446" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="396.493" y1="476.81" x2="388.512" y2="476.252" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="484.0" x2="400.0" y2="476.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="476.0" x2="400.0" y2="468.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="468.0" x2="400.0" y2="460.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="460.0" x2="406.709" y2="455.643" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="460.0" x2="395.411" y2="453.447" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="468.0" x2="395.761" y2="461.216" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="395.761" y1="461.216" x2="391.522" y2="454.432" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="391.522" y1="454.432" x2="398.075" y2="449.843" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="398.075" y1="449.843" x2="404.628" y2="445.254" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="391.522" y1="454.432" x2="383.566" y2="453.596" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="383.566" y1="453.596" x2="375.61" y2="452.76" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="468.0" x2="400.0" y2="460.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="460.0" x2="400.0" y2="452.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="452.0" x2="394.647" y2="446.055" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="394.647" y1="446.055" x2="395.483" y2="438.099" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="394.647" y1="446.055" x2="386.885" y2="447.99" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="452.0" x2="400.0" y2="444.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="444.0" x2="400.0" y2="436.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="436.0" x2="400.0" y2="428.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="428.0" x2="407.25" y2="424.619" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="428.0" x2="393.291" y2="423.643" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="436.0" x2="400.0" y2="428.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="428.0" x2="400.0" y2="420.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="420.0" x2="407.65" y2="417.661" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="407.65" y1="417.661" x2="415.3" y2="415.322" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="420.0" x2="393.447" y2="415.411" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="393.447" y1="415.411" x2="386.894" y2="410.822" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="436.0" x2="395.88" y2="429.143" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="395.88" y1="429.143" x2="391.76" y2="422.286" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="391.76" y1="422.286" x2="385.815" y2="416.933" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="385.815 ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-3d3b05ebf41d> in <cell line: 0>()
#      67
#      68 tree_instructions = create_l_system(tree_iterations, tree_axiom, tree_rules)
# ---> 69 draw_l_system_randAngle(tree_instructions, 8)
#
# <ipython-input-3-c20ee9c386f4> in draw_l_system_randAngle(instructions, distance)
#      83             position, heading = stack.pop()
#      84             t.penup()
# ---> 85             t.goto(position)
#      86             t.setheading(heading)
#      87             t.pendown()
#
# /usr/local/lib/python3.11/dist-packages/ColabTurtle/Turtle.py in goto(x, y)
#     323         raise ValueError('new y position must be a number.')
#     324     if y < 0:
# --> 325         raise ValueError('new y position must be non-negative.')
#     326     _moveToNewPosition((x, y))
#     327
#
# ValueError: new y position must be non-negative.

# %%
# Plant parameters
tree_axiom = "X"
possible_rules = [
    {
        "X": "F+[[X]-X]-F[-FX]+X",
        "F": "FF"
    },
    {
        "X": "F+[[X]-X]-F[-FX]++X",
        "F": "FF"
    },
    {
        "X": "F+[[X]--X]-F[-FX]+X",
        "F": "FF"
    },
    {
        "X": "F+[[+X]-X]-F[--FX]+X",
        "F": "FF"
    }
]
def randomize_rules():
  tree_rules = random.choice(possible_rules)

plant_iterations = 4


def reset_turtle():
  t.penup()
  t.goto(t.window_width() // 2, t.window_height())  # Start position
  t.pendown()
  t.setheading(270)
# Generate and draw
setup_turtle_bottom()
t.pensize(1)
randomize_rules()
plant_instructions = create_l_system(plant_iterations, tree_axiom, tree_rules)
draw_l_system_randAngle(plant_instructions,  10)
reset_turtle()
randomize_rules()
plant_instructions = create_l_system(plant_iterations, tree_axiom, tree_rules)
draw_l_system_randAngle(plant_instructions,  10)
reset_turtle()
randomize_rules()
plant_instructions = create_l_system(plant_iterations, tree_axiom, tree_rules)
draw_l_system_randAngle(plant_instructions,  10)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="500" x2="400.0" y2="490.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="490.0" x2="400.0" y2="480.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="480.0" x2="400.0" y2="470.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="470.0" x2="400.0" y2="460.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="460.0" x2="400.0" y2="450.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="450.0" x2="400.0" y2="440.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="440.0" x2="400.0" y2="430.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="430.0" x2="400.0" y2="420.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="420.0" x2="405.0" y2="411.34" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="405.0" y1="411.34" x2="410.0" y2="402.68" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="410.0" y1="402.68" x2="415.0" y2="394.02" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="415.0" y1="394.02" x2="420.0" y2="385.36" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="420.0" y1="385.36" x2="429.135" y2="381.293" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="429.135" y1="381.293" x2="438.27" y2="377.226" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="438.27" y1="377.226" x2="448.264" y2="377.575" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="448.264" y1="377.575" x2="458.167" y2="378.967" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="458.167" y1="378.967" x2="467.372" y2="375.06" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="438.27" y1="377.226" x2="445.584" y2="370.406" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="445.584" y1="370.406" x2="453.244" y2="363.978" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="453.244" y1="363.978" x2="454.463" y2="354.053" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="438.27" y1="377.226" x2="446.041" y2="370.933" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="446.041" y1="370.933" x2="453.812" y2="364.64" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="453.812" y1="364.64" x2="455.72" y2="354.824" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="455.72" y1="354.824" x2="457.628" y2="345.008" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="457.628" y1="345.008" x2="459.536" y2="335.192" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="459.536" y1="335.192" x2="462.292" y2="325.579" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="462.292" y1="325.579" x2="458.546" y2="316.307" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="453.812" y1="364.64" x2="462.472" y2="369.64" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="462.472" y1="369.64" x2="468.765" y2="377.411" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="468.765" y1="377.411" x2="477.828" y2="381.637" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="420.0" y1="385.36" x2="426.82" y2="378.046" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="426.82" y1="378.046" x2="433.64" y2="370.732" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="433.64" y1="370.732" x2="443.151" y2="367.642" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="443.151" y1="367.642" x2="452.999" y2="365.906" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="452.999" y1="365.906" x2="461.828" y2="361.211" stroke-linecap="round" style="stroke: ...

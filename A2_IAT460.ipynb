# %% [markdown]
# <a href="https://colab.research.google.com/github/owenc8/A2-Rule-Based-System/blob/main/A2_IAT460.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install ColabTurtle
# Out:
# Requirement already satisfied: ColabTurtle in /usr/local/lib/python3.11/dist-packages (2.1.0)

# %%
import ColabTurtle.Turtle as t
from IPython.display import clear_output
import random

# %% [markdown]
# lab 3 L system code

# %%
def create_l_system(iterations, axiom, rules):
    """Generate L-System instructions based on axiom and rules."""

    result = axiom
    for _ in range(iterations):
        new_string = ""

        for char in result:
            new_string += rules.get(char, char)
        result = new_string
    return result
def turtle_bounds():
  if t.xcor() > t.window_width() or t.xcor() < 0 or t.ycor() > t.window_height() or t.ycor() < 0:
    return True
  return False

def draw_l_system(instructions, angle, distance):
    """Draw the L-System using turtle graphics.

    Parameters:
    - instructions: string of L-System commands
    - angle: turning angle in degrees
    - distance: forward movement distance
    """

    stack = []
    for cmd in instructions:
        if cmd == 'F':  # Move forward and draw
            t.forward(distance)
        elif cmd == 'f':  # Move forward without drawing
            t.penup()
            t.forward(distance)
            t.pendown()
        elif cmd == '+':  # Turn right
            t.right(angle)
        elif cmd == '-':  # Turn left
            t.left(angle)
        elif cmd == '[':  # Save current state
            stack.append((t.position(), t.heading()))
        elif cmd == ']':  # Restore previous state
            position, heading = stack.pop()
            t.penup()
            t.goto(position)
            t.setheading(heading)
            t.pendown()

def setup_turtle():
        t.initializeTurtle()
        t.hideturtle()
        t.speed(13)  # Fastest speed
        t.penup()
        t.goto(t.window_width() // 2, t.window_height()-100)  # Start position
        t.pendown()

# %%
import random
# Your fractal tree parameters
tree_axiom = "X"  # Start with a single trunk
tree_rules = {
    "F": "F+F--F+F",
    "X": "F+[[X]-X]-F[-FX]+X"


}  # Basic branching rule
tree_iterations = 4
tree_angle = 90

#plant_axiom = "X"
# plant_rules = {
#     "X": "F+[[X]-X]-F[-FX]+X",
#     "F": "FF"
# }


# Generate and draw
setup_turtle()

red = 40
green = 40
blue = 255
t.pencolor(red,green,blue)
t.pensize(1)
tree_instructions = create_l_system(tree_iterations, tree_axiom, tree_rules)
for i in range(4):
    red+=10
    green+=10
    t.pencolor(red,green,blue)
    draw_l_system(tree_instructions, tree_angle, 10)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="400" x2="400.0" y2="390.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="400.0" y1="390.0" x2="410.0" y2="390.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="390.0" x2="400.0" y2="390.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="400.0" y1="390.0" x2="400.0" y2="380.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="400.0" y1="380.0" x2="410.0" y2="380.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="380.0" x2="410.0" y2="390.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="390.0" x2="410.0" y2="380.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="380.0" x2="420.0" y2="380.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="420.0" y1="380.0" x2="410.0" y2="380.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="380.0" x2="410.0" y2="370.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="370.0" x2="410.0" y2="380.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="380.0" x2="400.0" y2="380.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="400.0" y1="380.0" x2="400.0" y2="370.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="400.0" y1="370.0" x2="410.0" y2="370.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="370.0" x2="400.0" y2="370.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="400.0" y1="370.0" x2="400.0" y2="360.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="400.0" y1="360.0" x2="410.0" y2="360.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="360.0" x2="410.0" y2="370.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="370.0" x2="410.0" y2="360.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="360.0" x2="420.0" y2="360.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="420.0" y1="360.0" x2="420.0" y2="370.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="420.0" y1="370.0" x2="410.0" y2="370.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="410.0" y1="370.0" x2="420.0" y2="370.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="420.0" y1="370.0" x2="420.0" y2="380.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="420.0" y1="380.0" x2="420.0" y2="370.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="420.0" y1="370.0" x2="430.0" y2="370.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="430.0" y1="370.0" x2="420.0" y2="370.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="420.0" y1="370.0" x2="420.0" y2="360.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="420.0" y1="360.0" x2="430.0" y2="360.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="430.0" y1="360.0" x2="430.0" y2="370.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="430.0" y1="370.0" x2="430.0" y2="360.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="430.0" y1="360.0" x2="440.0" y2="360.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="440.0" y1="360.0" x2="430.0" y2="360.0" stroke-linecap="round" style="stroke:rgb(50,50,255);stroke-width:1"/><line x1="430.0" y1="360.0" x2="430.0" y2="350.0" stroke-linecap="rou ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-388768c7aa18> in <cell line: 0>()
#      31     green+=10
#      32     t.pencolor(red,green,blue)
# ---> 33     draw_l_system(tree_instructions, tree_angle, 10)
#      34
#
# <ipython-input-12-2884b8ca7ff0> in draw_l_system(instructions, angle, distance)
#      36             position, heading = stack.pop()
#      37             t.penup()
# ---> 38             t.goto(position)
#      39             t.setheading(heading)
#      40             t.pendown()
#
# /usr/local/lib/python3.11/dist-packages/ColabTurtle/Turtle.py in goto(x, y)
#     323         raise ValueError('new y position must be a number.')
#     324     if y < 0:
# --> 325         raise ValueError('new y position must be non-negative.')
#     326     _moveToNewPosition((x, y))
#     327
#
# ValueError: new y position must be non-negative.

# %%
# axiom = FX
# X -> X+YF+
# Y -> -FX-Y
# angle = 90
import random

# cool pattern
# tree_axiom = "FXX"  # Start with a single trunk
# tree_rules = {
#     "Y": "-FX-Y",
#     "X": "X+YF+"
# }

possible_axioms = ["FXY", "FX", "FXX", "FFX"]
possible_rules = [
    {
        "Y": "-FX-Y",
        "X": "X+YF+"
    },
    {
        "Y": "+FX+Y",
        "X": "X-YF-"
    },
    {
        "Y": "FX-Y",
        "X": "X+YF"
    },
    {
        "Y": "FX+Y",
        "X": "X-YF"
    }
]
tree_axiom = random.choice(possible_axioms)  # Randomly choose an axiom
tree_rules = random.choice(possible_rules)

print("Selected Axiom:", tree_axiom)
print("Selected Rules:", tree_rules)

 # Basic branching rule
tree_iterations = 8
tree_angle = random.randint(60,90)

size=2
# Generate and draw

setup_turtle()
def changeColour():
  red = random.randint(40,120)
  green = random.randint(100,255)
  blue = random.randint(220,255)
  t.pencolor(red,green,blue)


t.pensize(size)

# initial_color = (40, 40, 255)
red = 40
green = 40
blue = 255
t.pencolor(red,green,blue)
for i in range(3):

  t.pensize(size)
  changeColour()

  tree_instructions = create_l_system(tree_iterations, tree_axiom, tree_rules)
  draw_l_system(tree_instructions, tree_angle, 10)
# Out:
# Selected Axiom: FXY
# Selected Rules: {'Y': '+FX+Y', 'X': 'X-YF-'}
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="400" x2="400.0" y2="390.0" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="400.0" y1="390.0" x2="390.075" y2="388.781" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="390.075" y1="388.781" x2="387.656" y2="398.484" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="387.656" y1="398.484" x2="377.731" y2="397.265" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="377.731" y1="397.265" x2="375.312" y2="406.968" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="375.312" y1="406.968" x2="384.648" y2="410.552" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="384.648" y1="410.552" x2="382.229" y2="420.255" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="382.229" y1="420.255" x2="372.304" y2="419.036" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="372.304" y1="419.036" x2="369.885" y2="428.739" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="369.885" y1="428.739" x2="379.221" y2="432.323" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="379.221" y1="432.323" x2="383.916" y2="423.494" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="383.916" y1="423.494" x2="393.252" y2="427.078" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="393.252" y1="427.078" x2="390.833" y2="436.781" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="390.833" y1="436.781" x2="400.169" y2="440.365" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="400.169" y1="440.365" x2="397.75" y2="450.068" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="397.75" y1="450.068" x2="387.825" y2="448.849" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="387.825" y1="448.849" x2="385.406" y2="458.552" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="385.406" y1="458.552" x2="394.742" y2="462.136" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="394.742" y1="462.136" x2="399.437" y2="453.307" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="399.437" y1="453.307" x2="408.773" y2="456.891" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="408.773" y1="456.891" x2="413.468" y2="448.062" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="413.468" y1="448.062" x2="405.276" y2="442.326" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="405.276" y1="442.326" x2="409.971" y2="433.497" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="409.971" y1="433.497" x2="419.307" y2="437.081" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="419.307" y1="437.081" x2="416.888" y2="446.784" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="416.888" y1="446.784" x2="426.224" y2="450.368" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="426.224" y1="450.368" x2="430.919" y2="441.539" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="430.919" y1="441.539" x2="440.255" y2="445.123" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="440.255" y1="445.123" x2="437.836" y2="454.826" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="437.836" y1="454.826" x2="447.172" y2="458.41" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="447.172" y1="458.41" x2="444.753" y2="468.113" stroke-linecap="round" style="stroke:rgb(117,221,254);stroke-width:2"/><line x1="444 ...
